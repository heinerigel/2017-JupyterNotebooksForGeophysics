# %%
# Preparation for programming
# Make sure to execute this cell first!
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')                  # do not show warnings
from obspy import read
from obspy.core import read, UTCDateTime
from obspy.clients.fdsn import Client
import matplotlib.pylab as plt
import os
from os import path
import pandas as pd
from datetime import datetime

# %%
# Setting up parameters for getting waveforms
client = Client("IRIS")
t = UTCDateTime("2004-12-26T00:58:53.0")   # origin time of Sumatra earthquake
starttime = t-(1*24*60*60)                 # 1 day before the the origin time
endtime = t+(9*24*60*60)                   # 9 days after the the origin time

# %%
# Measure the download time
start = datetime.now()

# Downloading waveform data from the station list 1, 2, and 3
#sta_list = pd.read_csv('stationlist1.csv', sep=',',header=None)   # List 1
#sta_list = pd.read_csv('stationlist2.csv', sep=',',header=None)   # List 2
sta_list = pd.read_csv('stationlist3.csv', sep=',',header=None)   # List 3
sta_fname = sta_list[1] # list of file name
sta_code = sta_list[2]  # list of station code
sta_chan = sta_list[3]  # list of SEED channel
sta_loc = sta_list[4]   # list of SEED location
sta_net = sta_list[5]   # list of station network

# Download and save the raw waveform in a new directory
directory = "./data"
if not path.exists(directory):  # If data directory doesn't exist, it will create one
    os.makedirs(directory)

for i in range(len(sta_code)):
    st = client.get_waveforms(sta_net[i], sta_code[i], sta_loc[i], sta_chan[i],
                              starttime, endtime, attach_response=True)     # get the waveform
    st.resample(1.0)                                                        # resample the sampling rate
    st.merge(method=1, fill_value=0)                                        # merge the traces
    st.write(path.join(directory, sta_fname[i]), format = 'SAC')    # write and save the stream into SAC format
    print (st)

# Print download time
d = datetime.now() - start
print (d, " s")
# Out:
# 1 Trace(s) in Stream:
# IU.PMSA.00.LHZ | 2004-12-25T00:58:53.491121Z - 2005-01-04T00:58:52.491121Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.POHA.10.LHZ | 2004-12-25T00:58:53.760861Z - 2005-01-04T00:58:52.760861Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# G.PPT..LHZ | 2004-12-25T00:58:53.605200Z - 2005-01-04T00:58:51.605200Z | 1.0 Hz, 863999 samples
# 1 Trace(s) in Stream:
# IU.QSPA.00.LHZ | 2004-12-25T00:58:53.235652Z - 2005-01-04T00:58:52.235652Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.QSPA.10.LHZ | 2004-12-25T00:58:53.985646Z - 2005-01-04T00:58:52.985646Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.QSPA.20.LHZ | 2004-12-25T00:58:53.235652Z - 2005-01-04T00:58:52.235652Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.QSPA.30.LHZ | 2004-12-25T00:58:53.985646Z - 2005-01-04T00:58:52.985646Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.RAO.10.LHZ | 2004-12-25T12:29:05.485647Z - 2005-01-04T00:58:52.485647Z | 1.0 Hz, 822588 samples
# 1 Trace(s) in Stream:
# IU.RAR.00.LHZ | 2004-12-25T00:58:53.548129Z - 2005-01-04T00:58:52.548129Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.RAR.10.LHZ | 2004-12-25T00:58:53.548129Z - 2005-01-04T00:58:52.548129Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# II.RAYN.00.LHZ | 2004-12-25T00:58:53.612400Z - 2005-01-04T00:58:52.612400Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.RCBR.00.LHZ | 2004-12-25T00:58:53.873318Z - 2005-01-04T00:58:52.873318Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.RCBR.10.LHZ | 2004-12-25T00:58:53.873315Z - 2005-01-04T00:58:52.873315Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# G.RER.00.LHZ | 2004-12-25T00:58:53.000001Z - 2005-01-04T00:58:52.000001Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# II.RPN.00.LHZ | 2004-12-25T00:58:53.000000Z - 2005-01-04T00:58:53.000000Z | 1.0 Hz, 864001 samples
# 1 Trace(s) in Stream:
# II.RPN.10.LHZ | 2004-12-25T00:58:53.000000Z - 2005-01-04T00:58:53.000000Z | 1.0 Hz, 864001 samples
# 1 Trace(s) in Stream:
# IU.SBA.00.LHZ | 2004-12-25T00:58:53.010646Z - 2005-01-04T00:58:52.010646Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# G.SCZ..LHZ | 2004-12-25T00:58:53.518000Z - 2004-12-29T19:12:30.518000Z | 1.0 Hz, 411218 samples
# 1 Trace(s) in Stream:
# IU.SFJ.00.LHZ | 2004-12-25T00:58:53.998118Z - 2005-01-04T00:58:52.998118Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.SJG.00.LHZ | 2004-12-25T00:58:53.060646Z - 2005-01-04T00:58:52.060646Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.SNZO.00.LHZ | 2004-12-25T00:58:53.082225Z - 2005-01-04T00:58:53.082225Z | 1.0 Hz, 864001 samples
# 1 Trace(s) in Stream:
# IU.SNZO.10.LHZ | 2004-12-25T00:58:53.075983Z - 2005-01-04T00:58:53.075983Z | 1.0 Hz, 864001 samples
# 1 Trace(s) in Stream:
# G.SSB.00.LHZ | 2004-12-25T00:58:53.432338Z - 2005-01-04T00:58:52.432338Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.SSPA.00.LHZ | 2004-12-25T00:58:53.239162Z - 2005-01-04T00:58:52.239162Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# II.SUR.00.LHZ | 2004-12-25T00:58:53.425100Z - 2005-01-04T00:58:51.425100Z | 1.0 Hz, 863999 samples
# 1 Trace(s) in Stream:
# G.TAM..LHZ | 2004-12-25T00:58:53.869000Z - 2005-01-04T00:58:52.869000Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TATO.00.LHZ | 2004-12-25T00:58:53.485646Z - 2005-01-04T00:58:52.485646Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TATO.10.LHZ | 2004-12-25T00:58:53.485646Z - 2005-01-04T00:58:52.485646Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# II.TAU.00.LHZ | 2004-12-25T00:58:53.811800Z - 2005-01-04T00:58:52.811800Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TEIG.00.LHZ | 2004-12-25T00:58:53.220893Z - 2005-01-04T00:58:52.220893Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TEIG.10.LHZ | 2004-12-25T00:58:53.221176Z - 2005-01-04T00:58:52.221176Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TIXI.00.LHZ | 2004-12-25T00:58:53.821300Z - 2005-01-04T00:58:52.821300Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# II.TLY.00.LHZ | 2004-12-25T00:58:53.350000Z - 2005-01-04T00:58:52.350000Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TRQA.00.LHZ | 2004-12-25T00:58:53.959474Z - 2005-01-04T00:58:52.959474Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TRQA.10.LHZ | 2004-12-25T00:58:53.959474Z - 2005-01-04T00:58:52.959474Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.TUC.00.LHZ | 2004-12-25T00:58:53.547951Z - 2005-01-04T00:58:52.547951Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.ULN.00.LHZ | 2004-12-25T00:58:53.248109Z - 2005-01-04T00:58:52.248109Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# G.UNM..LHZ | 2004-12-25T00:58:53.226700Z - 2005-01-04T00:58:52.226700Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.WAKE.20.LHZ | 2004-12-25T00:58:53.860646Z - 2005-01-04T00:58:52.860646Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.WCI.00.LHZ | 2004-12-25T04:16:46.686938Z - 2005-01-04T00:58:52.686938Z | 1.0 Hz, 852127 samples
# 1 Trace(s) in Stream:
# II.WRAB.00.LHZ | 2004-12-25T00:58:53.000000Z - 2005-01-04T00:58:53.000000Z | 1.0 Hz, 864001 samples
# 1 Trace(s) in Stream:
# II.WRAB.10.LHZ | 2004-12-25T00:58:53.000000Z - 2005-01-04T00:58:53.000000Z | 1.0 Hz, 864001 samples
# 1 Trace(s) in Stream:
# G.WUS.00.LHZ | 2004-12-25T00:58:53.800337Z - 2005-01-03T01:13:49.800337Z | 1.0 Hz, 778497 samples
# 1 Trace(s) in Stream:
# IU.WVT..LHZ | 2004-12-25T00:58:53.272754Z - 2005-01-04T00:58:52.272754Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.YAK.00.LHZ | 2004-12-25T00:58:53.123146Z - 2005-01-04T00:58:52.123146Z | 1.0 Hz, 864000 samples
# 1 Trace(s) in Stream:
# IU.YSS.00.LHZ | 2004-12-25T00:58:53.785673Z - 2005-01-04T00:58:52.785673Z | 1.0 Hz, 864000 samples
# 0:40:21.201555  s

# %%
# Check the signal
sta_list = pd.read_csv('stationlist_mode_analysis.csv', sep=',',header=None)
sta_fname = sta_list[1] #list of file name
#fname = ['ABKT']    #specify the file name i.e. ABKT
#str = read ('ABKT') #read the data
str = read (sta_fname[41])
print (str)
str.plot()
